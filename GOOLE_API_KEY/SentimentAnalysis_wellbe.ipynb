# %% [markdown]
# ### Working Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks
# amazon_alexa.tsv  SentimentAnalysis_wellbe.ipynb

# %% [markdown]
# ### Import Dataset

# %%
import pandas as pd

data = pd.read_csv('amazon_alexa.tsv', sep='\t')
data.head(10)
# Out:
#    rating       date             variation  \
# 0       5  31-Jul-18      Charcoal Fabric
# 1       5  31-Jul-18      Charcoal Fabric
# 2       4  31-Jul-18        Walnut Finish
# 3       5  31-Jul-18      Charcoal Fabric
# 4       5  31-Jul-18      Charcoal Fabric
# 5       5  31-Jul-18  Heather Gray Fabric
# 6       3  31-Jul-18     Sandstone Fabric
# 7       5  31-Jul-18      Charcoal Fabric
# 8       5  30-Jul-18  Heather Gray Fabric
# 9       5  30-Jul-18  Heather Gray Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1
# 5  I received the echo as a gift. I needed anothe...         1
# 6  Without having a cellphone, I cannot use many ...         1
# 7  I think this is the 5th one I've purchased. I'...         1
# 8                                        looks great         1
# 9  Love it! I’ve listened to songs I haven’t hear...         1

# %%
mydata = data[['verified_reviews','feedback']]
mydata.columns = ['review','label']

mydata.head()
# Out:
#                                               review  label
# 0                                      Love my Echo!      1
# 1                                          Loved it!      1
# 2  Sometimes while playing a game, you can answer...      1
# 3  I have had a lot of fun with this thing. My 4 ...      1
# 4                                              Music      1

# %%
mydata.value_counts('label')
# Out:
# label
# 1    2893
# 0     257
# Name: count, dtype: int64

# %%
# Count the occurrences of each label
label_counts = mydata["label"].value_counts()

# Get the number of rows to drop from the majority class
rows_to_drop = label_counts.max() - label_counts.min()

# Drop rows from the majority class randomly
if rows_to_drop > 0:
   data_majority = mydata[mydata["label"] == 1]
   data_balanced = mydata.drop(data_majority.sample(rows_to_drop).index)
else:
   data_balanced = mydata.copy()

# Check the new class balance
print(data_balanced["label"].value_counts())
# Out:
# label
# 1    257
# 0    257
# Name: count, dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
import re

def clean_text(text):
  # Remove special characters and punctuation
  text = re.sub(r"[^\w\s]", " ", text)

  # Remove single characters
  text = re.sub(r"\b[a-zA-Z]\b", " ", text)

  # Remove HTML tags
  text = re.sub(r"<[^>]*>", " ", text)

  # Lowercase the text
  text = text.lower()

  # Remove extra whitespace
  text = re.sub(r"\s+", " ", text)

  # Trim leading and trailing spaces
  text = text.strip()

  return text

# %%
import pandas as pd

# Make sure the data inthe column are strings
data_balanced['review']=data_balanced['review'].apply(str)

# Extract the review column as a list
reviews = data_balanced['review'].tolist()


# Clean the text in the list
cleaned_reviews = [clean_text(review) for review in reviews]

# Add the cleaned reviews as a new column to the DataFrame
data_balanced['clean_reviews'] = cleaned_reviews

# %%
data_balanced
# Out:
#                                                  review  label  \
# 6     Without having a cellphone, I cannot use many ...      1
# 7     I think this is the 5th one I've purchased. I'...      1
# 22    Have only had it set up for a few days. Still ...      1
# 26    I love my Echo. It's easy to operate, loads of...      1
# 27                            Sounds great!! Love them!      1
# ...                                                 ...    ...
# 3097                               I have a friend now.      1
# 3099                                        Good device      1
# 3124  Love my Alexa! Actually have 3 throughout the ...      1
# 3129  We have six of these throughout our home and t...      1
# 3134                                         PHENOMENAL      1
#
#                                           clean_reviews
# 6     without having cellphone cannot use many of he...
# 7     think this is the 5th one ve purchased working...
# 22    have only had it set up for few days still add...
# 26    love my echo it easy to operate loads of fun i...
# 27                               sounds great love them
# ...                                                 ...
# 3097                                    have friend now
# 3099                                        good device
# 3124  love my alexa actually have 3 throughout the h...
# 3129  we have six of these throughout our home and t...
# 3134                                         phenomenal
#
# [514 rows x 3 columns]

# %% [markdown]
# ## Data Split

# %%
import pandas as pd

# Assuming your DataFrame is called "df"
total_rows = len(data_balanced)
test_size = int(total_rows * 0.95)

# Randomly sample train_size rows for the training set
test_set = data_balanced.sample(test_size)

# Get the remaining rows for the test set
train_set = data_balanced.drop(test_set.index)

# %% [markdown]
# ## Sentiment w/ LLM

# %% [markdown]
# ### Setting up Gemini API

# %%
# !pip install -q -U google-generativeai

# %%
# Necessary packages
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Used to securely store your API key
from google.colab import userdata

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
# %%time
response = model.generate_content("What is the meaning of life?")

to_markdown(response.text)
# Out:
# CPU times: user 90.8 ms, sys: 12 ms, total: 103 ms
# Wall time: 5.92 s
# > The meaning of life is a question that has been pondered by philosophers, theologians, and scientists for millennia. There is no one definitive answer, and the meaning of life may be different for different people. Some common answers to the question include:
# >
# > * **To find happiness and fulfillment**
# > * **To make a difference in the world**
# > * **To connect with others**
# > * **To learn and grow**
# > * **To serve a higher purpose**
# >
# > Ultimately, the meaning of life is something that each individual must determine for themselves. There is no right or wrong answer, and the search for meaning can be a lifelong journey.
# >
# > Here are some additional thoughts on the meaning of life:
# >
# > * **The meaning of life is not static**. It can change as we grow and change throughout our lives.
# > * **The meaning of life is not something that is found**. It is something that is created.
# > * **The meaning of life is not something that is given to us**. It is something that we must find for ourselves.
# >
# > The search for meaning can be a difficult and challenging one. However, it is a worthwhile one. Finding meaning in our lives can lead to greater happiness, fulfillment, and purpose.

# %% [markdown]
# #### Single API Call

# %%
test_set_sample = test_set.sample(20)

## Creating a new column for prediction generative model
test_set_sample['pred_label'] = ''

test_set_sample
# Out:
#                                                  review  label  \
# 526                                    Not good at all!      0
# 2784               I loved it does exactly what it says      1
# 836                                  Not much features.      0
# 324   We really only use this as a speaker to stream...      1
# 484   A small problem out of the box, but a rep from...      1
# 2177  I already bought one previously to try out and...      1
# 2687                          Perfect for a home office      1
# 1425  Needs to play YouTube and prime video and mayb...      1
# 1935  wish it had a battery or was described better ...      0
# 1903           Terrible. Stopped working after one day.      0
# 2543  Some times Alexa is a little &#34;thick&#34;, ...      1
# 2779          Use the product for music and it’s great!      1
# 2876                                                         0
# 841   I have had Alexa since the beginning.  I accid...      1
# 350   Item no longer works after just 5 months of us...      0
# 2979                                                         0
# 3129  We have six of these throughout our home and t...      1
# 1798  Great product. I have two and may want to buy ...      1
# 2898  Clear sound, great alarm clock, plays my music...      1
# 2512                                      Great product      1
#
#                                           clean_reviews pred_label
# 526                                     not good at all
# 2784                 loved it does exactly what it says
# 836                                   not much features
# 324   we really only use this as speaker to stream m...
# 484   small problem out of the box but rep from amaz...
# 2177  already bought one previously to try out and e...
# 2687                            perfect for home office
# 1425  needs to play youtube and prime video and mayb...
# 1935  wish it had battery or was described better as...
# 1903             terrible stopped working after one day
# 2543  some times alexa is little 34 thick 34 but mos...
# 2779             use the product for music and it great
# 2876
# 841   have had alexa since the beginning accidentall...
# 350   item no longer works after just 5 months of us...
# 2979
# 3129  we have six of these throughout our home and t...
# 1798   great product have two and may want to buy third
# 2898  clear sound great alarm clock plays my music w...
# 2512                                      great product

# %%
# Convert the DataFrame to JSON using the to_json() method

json_data = test_set_sample[['clean_reviews','pred_label']].to_json(orient='records')

# Print the JSON data
print(json_data)
# Out:
# [{"clean_reviews":"not good at all","pred_label":""},{"clean_reviews":"loved it does exactly what it says","pred_label":""},{"clean_reviews":"not much features","pred_label":""},{"clean_reviews":"we really only use this as speaker to stream music we ve had it 7 months and it just kinda useless","pred_label":""},{"clean_reviews":"small problem out of the box but rep from amazon called and walked me through reset process which solved my issues was shocked to get response so quickly and real effort was made including follow up email to get this thing working have 6 now and one google clone and the more use it and learn about it the more like it them also plan to install one in my car boat and garage alexa is my new best friend lol think gf is worried that if alexa learns to cook her time will be limited","pred_label":""},{"clean_reviews":"already bought one previously to try out and enjoyed it bought these new ones during the prime sale","pred_label":""},{"clean_reviews":"perfect for home office","pred_label":""},{"clean_reviews":"needs to play youtube and prime video and maybe netflix but it has good sound","pred_label":""},{"clean_reviews":"wish it had battery or was described better as plug in only item","pred_label":""},{"clean_reviews":"terrible stopped working after one day","pred_label":""},{"clean_reviews":"some times alexa is little 34 thick 34 but mostly good","pred_label":""},{"clean_reviews":"use the product for music and it great","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"have had alexa since the beginning accidentally spilled water on her and have replaced it with the 2nd generation decided couldn be without an echo setup was easy and had it working within minutes","pred_label":""},{"clean_reviews":"item no longer works after just 5 months of use will not connect to wifi and unresponsive to reset requests","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"we have six of these throughout our home and they are great there are times when music or talking happens randomly that may be from sensitive listening there should be more options to change the name of the engagement command 34 alexa 34 or 34 computer 34 are little annoying more colors then black and white would also be good thing","pred_label":""},{"clean_reviews":"great product have two and may want to buy third","pred_label":""},{"clean_reviews":"clear sound great alarm clock plays my music what else can you ask for oh yeah you can order what you need","pred_label":""},{"clean_reviews":"great product","pred_label":""}]

# %%
prompt = f"""
You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
Customer reviews are provided between three back ticks.
In your output, only return the Json code back as output - which is provided between three backticks.
Your task is to update predicted labels under 'pred_label' in the Json code.
Don't make any changes to Json code format, please.

```
{json_data}
```
"""

print(prompt)
# Out:
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
# Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
# Customer reviews are provided between three back ticks.
# In your output, only return the Json code back as output - which is provided between three backticks.
# Your task is to update predicted labels under 'pred_label' in the Json code.
# Don't make any changes to Json code format, please.
#
# ```
# [{"clean_reviews":"not good at all","pred_label":""},{"clean_reviews":"loved it does exactly what it says","pred_label":""},{"clean_reviews":"not much features","pred_label":""},{"clean_reviews":"we really only use this as speaker to stream music we ve had it 7 months and it just kinda useless","pred_label":""},{"clean_reviews":"small problem out of the box but rep from amazon called and walked me through reset process which solved my issues was shocked to get response so quickly and real effort was made including follow up email to get this thing working have 6 now and one google clone and the more use it and learn about it the more like it them also plan to install one in my car boat and garage alexa is my new best friend lol think gf is worried that if alexa learns to cook her time will be limited","pred_label":""},{"clean_reviews":"already bought one previously to try out and enjoyed it bought these new ones during the prime sale","pred_label":""},{"clean_reviews":"perfect for home office","pred_label":""},{"clean_reviews":"needs to play youtube and prime video and maybe netflix but it has good sound","pred_label":""},{"clean_reviews":"wish it had battery or was described better as plug in only item","pred_label":""},{"clean_reviews":"terrible stopped working after one day","pred_label":""},{"clean_reviews":"some times alexa is little 34 thick 34 but mostly good","pred_label":""},{"clean_reviews":"use the product for music and it great","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"have had alexa since the beginning accidentally spilled water on her and have replaced it with the 2nd generation decided couldn be without an echo setup was easy and had it working within minutes","pred_label":""},{"clean_reviews":"item no longer works after just 5 months of use will not connect to wifi and unresponsive to reset requests","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"we have six of these throughout our home and they are great there are times when music or talking happens randomly that may be from sensitive listening there should be more options to change the name of the engagement command 34 alexa 34 or 34 computer 34 are little annoying more colors then black and white would also be good thing","pred_label":""},{"clean_reviews":"great product have two and may want to buy third","pred_label":""},{"clean_reviews":"clear sound great alarm clock plays my music what else can you ask for oh yeah you can order what you need","pred_label":""},{"clean_reviews":"great product","pred_label":""}]
# ```

# %%
response = model.generate_content(prompt)

print(response.text)
# Out:
# ```
# [{"clean_reviews":"not good at all","pred_label":0},{"clean_reviews":"loved it does exactly what it says","pred_label":1},{"clean_reviews":"not much features","pred_label":0},{"clean_reviews":"we really only use this as speaker to stream music we ve had it 7 months and it just kinda useless","pred_label":0},{"clean_reviews":"small problem out of the box but rep from amazon called and walked me through reset process which solved my issues was shocked to get response so quickly and real effort was made including follow up email to get this thing working have 6 now and one google clone and the more use it and learn about it the more like it them also plan to install one in my car boat and garage alexa is my new best friend lol think gf is worried that if alexa learns to cook her time will be limited","pred_label":1},{"clean_reviews":"already bought one previously to try out and enjoyed it bought these new ones during the prime sale","pred_label":1},{"clean_reviews":"perfect for home office","pred_label":1},{"clean_reviews":"needs to play youtube and prime video and maybe netflix but it has good sound","pred_label":0},{"clean_reviews":"wish it had battery or was described better as plug in only item","pred_label":0},{"clean_reviews":"terrible stopped working after one day","pred_label":0},{"clean_reviews":"some times alexa is little 34 thick 34 but mostly good","pred_label":1},{"clean_reviews":"use the product for music and it great","pred_label":1},{"clean_reviews":"","pred_label":0},{"clean_reviews":"have had alexa since the beginning accidentally spilled water on her and have replaced it with the 2nd generation decided couldn be without an echo setup was easy and had it working within minutes","pred_label":1},{"clean_reviews":"item no longer works after just 5 months of use will not connect to wifi and unresponsive to reset requests","pred_label":0},{"clean_reviews":"","pred_label":0},{"clean_reviews":"we have six of these throughout our home and they are great there are times when music or talking happens randomly that may be from sensitive listening there should be more options to change the name of the engagement command 34 alexa 34 or 34 computer 34 are little annoying more colors then black and white would also be good thing","pred_label":1},{"clean_reviews":"great product have two and may want to buy third","pred_label":1},{"clean_reviews":"clear sound great alarm clock plays my music what else can you ask for oh yeah you can order what you need","pred_label":1},{"clean_reviews":"great product","pred_label":1}]
# ```

# %%
import json

# Clean the data by stripping the backticks
json_data = response.text.strip("`")

# Load the cleaned data and convert to DataFrame
data = json.loads(json_data)
df_sample = pd.DataFrame(data)

df_sample
# Out:
#                                         clean_reviews  pred_label
# 0                                     not good at all           0
# 1                  loved it does exactly what it says           1
# 2                                   not much features           0
# 3   we really only use this as speaker to stream m...           0
# 4   small problem out of the box but rep from amaz...           1
# 5   already bought one previously to try out and e...           1
# 6                             perfect for home office           1
# 7   needs to play youtube and prime video and mayb...           0
# 8   wish it had battery or was described better as...           0
# 9              terrible stopped working after one day           0
# 10  some times alexa is little 34 thick 34 but mos...           1
# 11             use the product for music and it great           1
# 12                                                              0
# 13  have had alexa since the beginning accidentall...           1
# 14  item no longer works after just 5 months of us...           0
# 15                                                              0
# 16  we have six of these throughout our home and t...           1
# 17   great product have two and may want to buy third           1
# 18  clear sound great alarm clock plays my music w...           1
# 19                                      great product           1

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_sample['pred_label'] = df_sample['pred_label'].values
test_set_sample
# Out:
#                                                  review  label  \
# 526                                    Not good at all!      0
# 2784               I loved it does exactly what it says      1
# 836                                  Not much features.      0
# 324   We really only use this as a speaker to stream...      1
# 484   A small problem out of the box, but a rep from...      1
# 2177  I already bought one previously to try out and...      1
# 2687                          Perfect for a home office      1
# 1425  Needs to play YouTube and prime video and mayb...      1
# 1935  wish it had a battery or was described better ...      0
# 1903           Terrible. Stopped working after one day.      0
# 2543  Some times Alexa is a little &#34;thick&#34;, ...      1
# 2779          Use the product for music and it’s great!      1
# 2876                                                         0
# 841   I have had Alexa since the beginning.  I accid...      1
# 350   Item no longer works after just 5 months of us...      0
# 2979                                                         0
# 3129  We have six of these throughout our home and t...      1
# 1798  Great product. I have two and may want to buy ...      1
# 2898  Clear sound, great alarm clock, plays my music...      1
# 2512                                      Great product      1
#
#                                           clean_reviews  pred_label
# 526                                     not good at all           0
# 2784                 loved it does exactly what it says           1
# 836                                   not much features           0
# 324   we really only use this as speaker to stream m...           0
# 484   small problem out of the box but rep from amaz...           1
# 2177  already bought one previously to try out and e...           1
# 2687                            perfect for home office           1
# 1425  needs to play youtube and prime video and mayb...           0
# 1935  wish it had battery or was described better as...           0
# 1903             terrible stopped working after one day           0
# 2543  some times alexa is little 34 thick 34 but mos...           1
# 2779             use the product for music and it great           1
# 2876                                                              0
# 841   have had alexa since the beginning accidentall...           1
# 350   item no longer works after just 5 months of us...           0
# 2979                                                              0
# 3129  we have six of these throughout our home and t...           1
# 1798   great product have two and may want to buy third           1
# 2898  clear sound great alarm clock plays my music w...           1
# 2512                                      great product           1

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_true = test_set_sample["label"]
y_pred = test_set_sample["pred_label"]

confusion_matrix(y_true, y_pred)

## For a better display
y_test = test_set_sample["label"]
predictions = test_set_sample["pred_label"]

cm = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# ### OpenAI API Config

# %%
# !pip install openai==0.27.0
# Out:
# Collecting openai==0.27.0
#   Downloading openai-0.27.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.27.0) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.27.0) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.27.0) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.0) (2023.11.17)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.0) (4.0.3)
# Installing collected packages: openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed openai-0.27.0

# %%
import openai
from google.colab import userdata

OPENAI_API_KEY=userdata.get('OPENAI_API_KEY')
openai.api_key  = OPENAI_API_KEY

# %%
def get_completion(prompt, model="gpt-3.5-turbo-1106"):

  messages = [{"role": "user", "content": prompt}]
  response = openai.ChatCompletion.create(model=model,messages=messages,temperature=0)

  return response.choices[0].message["content"]

# %%
prompt = "Why is the sky blue?"

chatgpt_response = get_completion(prompt)

# %%
chatgpt_response
# Out:
# "The sky appears blue to our eyes because of the way the Earth's atmosphere scatters sunlight. The molecules in the Earth's atmosphere, particularly nitrogen and oxygen, scatter shorter wavelengths of light (blue and violet) more effectively than longer wavelengths (red and yellow). This scattering causes the blue light to be more visible and gives the sky its blue color. This effect is known as Rayleigh scattering."

# %% [markdown]
# #### Batching API Calls (Single Shot)

# %%
test_set.shape
# Out:
# (488, 3)

# %%
test_set_total = test_set.sample(100)

test_set_total['pred_label'] = ''

test_set_total
# Out:
#                                                  review  label  \
# 2786                                    Very convenient      1
# 1913  Excellent why didn’t I think it is in the begi...      1
# 2621                                            Love it      1
# 672   Bought this to go in my niece's room. You can'...      1
# 2225  The current demand for this stick, was too hig...      1
# ...                                                 ...    ...
# 653   I wanted a white dot for my white bathroom.  T...      0
# 857   Stopped working after 2 weeks ,didn't follow c...      0
# 2005  Why do we need to buy a $100 hub to get it to ...      0
# 1342  I am very excited and happy with this. It was ...      1
# 1357  In one word: Amazing! Best tech purchase I hav...      1
#
#                                           clean_reviews pred_label
# 2786                                    very convenient
# 1913  excellent why didn think it is in the beginnin...
# 2621                                            love it
# 672   bought this to go in my niece room you can tel...
# 2225  the current demand for this stick was too high...
# ...                                                 ...        ...
# 653   wanted white dot for my white bathroom the top...
# 857   stopped working after 2 weeks didn follow comm...
# 2005  why do we need to buy 100 hub to get it to wor...
# 1342  am very excited and happy with this it was bre...
# 1357  in one word amazing best tech purchase have ev...
#
# [100 rows x 4 columns]

# %%
batches = []
batch_size = 50

for i in range(0, len(test_set_total), batch_size):
  batches.append(test_set_total[i : i + batch_size])  # Append batches instead of assigning

# %%
import time

def gpt_completion_function(batch,current_batch,total_batch,model="gpt-3.5-turbo-1106"):
  """Function works in three steps:
  # Step-1: Convert the DataFrame to JSON using the to_json() method.
  # Step-2: Preparing the Gemini Prompt
  # Step-3: Calling GPT API
  """

  print(f"Now processing batch#: {current_batch+1} of {total_batch}")

  json_data = batch[['clean_reviews','pred_label']].to_json(orient='records')

  prompt = f"""You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
  Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
  Customer reviews are provided between three backticks below.
  In your output, only return the Json code back as output - which is provided between three backticks.
  Your task is to update predicted labels under 'pred_label' in the Json code.
  Don't make any changes to Json code format, please.
  Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).

  ```
  {json_data}
  ```
  """

  print(prompt)

  messages = [{"role": "user", "content": prompt}]
  response = openai.ChatCompletion.create(model=model,messages=messages,temperature=0)
  time.sleep(5)
  return response.choices[0].message["content"]

# %%
batch_count = len(batches)
responses = []

for i in range(0,len(batches)):
  responses.append(gpt_completion_function(batches[i],i,batch_count))
# Out:
# Now processing batch#: 1 of 2
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"very convenient","pred_label":""},{"clean_reviews":"excellent why didn think it is in the beginning love it","pred_label":""},{"clean_reviews":"love it","pred_label":""},{"clean_reviews":"bought this to go in my niece room you can tell it refurbished it looks good and works like new","pred_label":""},{"clean_reviews":"the current demand for this stick was too high for the power coming out of my usb port on the tv had to run the power cable to the supplied usb adapter not big deal but added another cable showing on my wall mounted tv","pred_label":""},{"clean_reviews":"not all that happy the speaker isn great and for some reason lot of times when play music it will start to make some weird noise and just stop my son has google home and it is much better","pred_label":""},{"clean_reviews":"have had for only week so am still learning all that alexa can do it is learning process love the music can call up any time listen to podcasts and radio stations have just started keeping shopping lists and grocery lists which love don have to search for paper and pencil getting time and temperature are great do not have to wait for weather reports the sound is good am not fussy about woofers tweeters base etc the echo is fine for me this afternoon am going to try dropping in on my son when he gets home going to surprise him","pred_label":""},{"clean_reviews":"very impressed with look clarity of sound and color","pred_label":""},{"clean_reviews":"terrific sound for small device and nice form factor for the nightstand like the convenience of seeing the time and temperature rather than asking alexa not using video much but it would be nice if the device had square rectangular screen","pred_label":""},{"clean_reviews":"didn like that almost everytime asked alexa question she would say dont know that or havent learned that","pred_label":""},{"clean_reviews":"it sucks","pred_label":""},{"clean_reviews":"sound is terrible cannot pair with echo to play simultaneously must upgrade to amazon music if you want to play more than one device at time","pred_label":""},{"clean_reviews":"echo show is said to work with certain apps but not cozi state works with echo show but the cozi family doesn very well amazon needs to go back to drawing board it would be such needed piece of technology but it lacks the essential please fix cost of the echo show was marvelous got echo show to take on shopping list but that is all so far adding items to list has long lag and it not my router being slow my provider speed is gb speed not problem but before new items is updated on cozi is very slow help is needed to get it updated to a1 working conditioning","pred_label":""},{"clean_reviews":"este producto lleg\u00f3 la semana se qued\u00f3 sin olor perdi\u00f3 toda su escencia huele solo alcohol","pred_label":""},{"clean_reviews":"so far not impressed at all does not save groups correctly can not understand me most of the time not sure what the excitement is all about alexas voice sounds like it under water how am supposed to understand going to return and try google home","pred_label":""},{"clean_reviews":"works great perfect for my office","pred_label":""},{"clean_reviews":"great size for bedside plus it dims at night","pred_label":""},{"clean_reviews":"can turn of 34 things to try 34 on the screen scroll this is big promotion device for amazon packing it up and sending it back they really want to get in our heads enough already","pred_label":""},{"clean_reviews":"like everything about it","pred_label":""},{"clean_reviews":"the only negative we have on this product is the terrible sound quality massive difference from the alexa which to us was big reason we wanted to purchase this won be buying another until the speaker and sound quality can improve","pred_label":""},{"clean_reviews":"extremely low in volume","pred_label":""},{"clean_reviews":"sad joke worthless","pred_label":""},{"clean_reviews":"not working","pred_label":""},{"clean_reviews":"all the  ...
#   ```
#
# Now processing batch#: 2 of 2
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"really disappointed alexa has to be plug in to wall socket all the time my fault for not checking this but made the assumption that company has technologically advanced as amazon would sell this product with rechargeable battery if could return it would as my apple music and boom speaker give me more flexibility the alexa","pred_label":""},{"clean_reviews":"this is great item and just added audible books which makes it even better thank you","pred_label":""},{"clean_reviews":"when we first received this product it was great however about week ago the device served up video advertisement around 10 30pm at night and scared myself and my family if you want to make sure you are protected and don allow video directly in your home the spot is not device that can keep you safe","pred_label":""},{"clean_reviews":"love my echo dot the price paid during prime day was comparable to buying new digital clock with the bells and whistles but this does so much more can play music set alarms call friends play games set timers the list goes on and on definitely worth the money","pred_label":""},{"clean_reviews":"works great upgraded from echo dot to full size echo couldn be happier","pred_label":""},{"clean_reviews":"sound is terrible if want good music too get bose","pred_label":""},{"clean_reviews":"too difficult to set up it keeps timing out before you can enter the password","pred_label":""},{"clean_reviews":"not happy with the spot reset numerous times seems to be in slow mode have to be practically on top of it for it to hear me even after talking with support still do not have themes in the menu to choose from","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"have the original alexa and the tap and so far the 2nd generation is the best happy to see they are making improvements with each new one it would be great to have updates to our little think it would help out lot with the bugs in it all in all am very happy with her and can now play music throughout the whole house and adjust the bass and treble thank you","pred_label":""},{"clean_reviews":"it got great sound and bass but it doesn work all of the time its still hot or miss when it recognizes things","pred_label":""},{"clean_reviews":"met every expectation had","pred_label":""},{"clean_reviews":"ve only got to use it for couple of weeks before having to go into the hospital but had good time with it for the short time did use it it was fun trying to use alexa","pred_label":""},{"clean_reviews":"best looking echo device easy to use","pred_label":""},{"clean_reviews":"am very pleased with the echo show love that it has so many nice features highly recommend it","pred_label":""},{"clean_reviews":"great device seems to work better than the 1st generation","pred_label":""},{"clean_reviews":"love these great in the bathroom to listen to the news during showering or listen to cnn live with serius sm","pred_label":""},{"clean_reviews":"stopped working after 7 months the warranty was only good for 3 months would have assumed an amazon product sold on amazon would have had higher standards than guaranteeing that it would work for 3 whole months mean what is this product supposed to be piece of junk they offered my 15 discount if wanted to buy another one why would want to buy another one","pred_label":""},{"clean_reviews":"not good at all","pred_label":""},{"clean_reviews":"device has great speakers and the screen quality is phenomenal","pred_label":""},{"clean_reviews":"switched to google the amazon helper is more for shopping and google is the tasks assistant","pred_label":""},{"clean_reviews":"smaller than thought it would be happy got stand so it sits up higher on the bedside table","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"love the echo dot it amaxing","pred_label":""},{"clean_reviews":"it not as good as siri but it still has some positives it great at playing music and setting alarms personally felt that paid too  ...
#   ```

# %%
import json

df_total = pd.DataFrame()  # Initialize an empty DataFrame

for response in responses:
  # Clean the data by stripping the backticks
  json_data = response.strip("`")

  # Load the cleaned data and convert to DataFrame
  data = json.loads(json_data)
  df_temp = pd.DataFrame(data)

  # Append the DataFrame to the final DataFrame
  df_total = df_total.append(df_temp, ignore_index=True)

print(df_total)  # Display the final DataFrame
# Out:
#                                         clean_reviews  pred_label
# 0                                     very convenient           1
# 1   excellent why didn think it is in the beginnin...           1
# 2                                             love it           1
# 3   bought this to go in my niece room you can tel...           1
# 4   the current demand for this stick was too high...           0
# ..                                                ...         ...
# 95  wanted white dot for my white bathroom the top...           0
# 96  stopped working after 2 weeks didn follow comm...           0
# 97  why do we need to buy 100 hub to get it to wor...           0
# 98  am very excited and happy with this it was bre...           1
# 99  in one word amazing best tech purchase have ev...           1
#
# [100 rows x 2 columns]
# <ipython-input-34-6f10fdd72bc6>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total = df_total.append(df_temp, ignore_index=True)
# <ipython-input-34-6f10fdd72bc6>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total = df_total.append(df_temp, ignore_index=True)

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_total['pred_label'] = df_total['pred_label'].values
test_set_total
# Out:
#                                                  review  label  \
# 2786                                    Very convenient      1
# 1913  Excellent why didn’t I think it is in the begi...      1
# 2621                                            Love it      1
# 672   Bought this to go in my niece's room. You can'...      1
# 2225  The current demand for this stick, was too hig...      1
# ...                                                 ...    ...
# 653   I wanted a white dot for my white bathroom.  T...      0
# 857   Stopped working after 2 weeks ,didn't follow c...      0
# 2005  Why do we need to buy a $100 hub to get it to ...      0
# 1342  I am very excited and happy with this. It was ...      1
# 1357  In one word: Amazing! Best tech purchase I hav...      1
#
#                                           clean_reviews  pred_label
# 2786                                    very convenient           1
# 1913  excellent why didn think it is in the beginnin...           1
# 2621                                            love it           1
# 672   bought this to go in my niece room you can tel...           1
# 2225  the current demand for this stick was too high...           0
# ...                                                 ...         ...
# 653   wanted white dot for my white bathroom the top...           0
# 857   stopped working after 2 weeks didn follow comm...           0
# 2005  why do we need to buy 100 hub to get it to wor...           0
# 1342  am very excited and happy with this it was bre...           1
# 1357  in one word amazing best tech purchase have ev...           1
#
# [100 rows x 4 columns]

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix, accuracy_score

y_true = test_set_total["label"]
y_pred = test_set_total["pred_label"]

print(confusion_matrix(y_true, y_pred))
print(f"\nAccuracy: {accuracy_score(y_true, y_pred)}")
# Out:
# [[46  0]
#  [ 9 45]]
#
# Accuracy: 0.91

# %% [markdown]
# ### Batching API Calls: Gemini API

# %%
test_set.shape
# Out:
# (488, 3)

# %%
test_set_total = test_set.sample(100)

test_set_total['pred_label'] = ''

test_set_total
# Out:
#                                                  review  label  \
# 1625  Our family bought several of these to help com...      0
# 1918  I am so disappointed in this product.  I tried...      0
# 678   Love our echo! Thing the full size version sou...      1
# 2017  Easy to Install. Very clear speaker. I took on...      1
# 1473  Do not understand all the excitement over thes...      0
# ...                                                 ...    ...
# 462   outstanding I use all the time....works just l...      1
# 2023  Unit came with the wrong plug, will have to se...      0
# 976                                easy to use--amazing      1
# 382                         Poor quality. Gave it away.      0
# 638             Just like new, set-up was quick & easy.      1
#
#                                           clean_reviews pred_label
# 1625  our family bought several of these to help com...
# 1918  am so disappointed in this product tried to in...
# 678   love our echo thing the full size version soun...
# 2017  easy to install very clear speaker took one st...
# 1473  do not understand all the excitement over thes...
# ...                                                 ...        ...
# 462   outstanding use all the time works just like t...
# 2023  unit came with the wrong plug will have to sen...
# 976                                 easy to use amazing
# 382                           poor quality gave it away
# 638                 just like new set up was quick easy
#
# [100 rows x 4 columns]

# %%
batches = []
batch_size = 25

for i in range(0, len(test_set_total), batch_size):
  batches.append(test_set_total[i : i + batch_size])  # Append batches instead of assigning

# %%
import time

def gemini_completion_function(batch,current_batch,total_batch):
  """Function works in three steps:
  # Step-1: Convert the DataFrame to JSON using the to_json() method.
  # Step-2: Preparing the Gemini Prompt
  # Step-3: Calling Gemini API
  """

  print(f"Now processing batch#: {current_batch+1} of {total_batch}")

  json_data = batch[['clean_reviews','pred_label']].to_json(orient='records')

  prompt = f"""You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
  Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
  Customer reviews are provided between three backticks below.
  In your output, only return the Json code back as output - which is provided between three backticks.
  Your task is to update predicted labels under 'pred_label' in the Json code.
  Don't make any changes to Json code format, please.
  Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).

  ```
  {json_data}
  ```
  """

  print(prompt)
  response = model.generate_content(prompt)
  time.sleep(5)

  return response

# %%
batch_count = len(batches)
responses = []

for i in range(0,len(batches)):
  responses.append(gemini_completion_function(batches[i],i,batch_count))
# Out:
# Now processing batch#: 1 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"our family bought several of these to help communicate with older parents and grandparents who need simpler devices than full fledged tablet what fantastic potential these have for digital photo screen video calls easy accesss to music audio books etc however once we have them setup we discovered the huge lurking negative amazon forces you to view continous spam on the home screen promoting all their alexa features you can turn off many other things in settins but you cannot turn off 34 things to try 34 instead of beautiful digital photo screen with weather and time we now constantly have spam ad across the home screen that says 34 try 34 amazon please listen to your customers and offer setting to turn off this spam","pred_label":""},{"clean_reviews":"am so disappointed in this product tried to install two different units and neither one of them were successfully completed hours with amazon technicians resetting each of them the app didn connect the echo plus to the internet connection tried using the application on phone tablet and on chromebook no luck there are no clean directions on the application probably sending this back to amazon mark this as not ready for prime time","pred_label":""},{"clean_reviews":"love our echo thing the full size version sounds better though","pred_label":""},{"clean_reviews":"easy to install very clear speaker took one star off because it was delivered late by ontrac like usual","pred_label":""},{"clean_reviews":"do not understand all the excitement over these alexa devices or the google ones either it rarely gets what say correct does not control the dish receiver yes set it up correctly using the alexa app on my phone we got this for 129 which is good deal ti is definately not worth the 229 price though maybe in another month it will get better or either have one that is just deaf and dumb really can not recommend this item at the current time","pred_label":""},{"clean_reviews":"great sound quality works well with smart home devices","pred_label":""},{"clean_reviews":"menu doesn work says it can connect to amazon network","pred_label":""},{"clean_reviews":"new to alexa like this spot lot","pred_label":""},{"clean_reviews":"the echo part works fine the hue hub is disaster it worked for few months and then nothing spent 2 hours on the phone with tech support one to have to send it in for repair am now trying to reconnect my lights what pain am having to reset each light bulb it can take up to 5 times to get it to reset have spent hours on this will say customer service was friendly and tried to be helpful stick with the echo and smart plugs for lamps","pred_label":""},{"clean_reviews":"disappointed that this device is not able to access youtube as of dec 2017 wasn aware of that when purchased it ve had problems with my device the voice stops working throughout the day can see it trying to respond to me because the window it opens contains the info asked about but it like the device gets stuck in the process it stops working and the blue bar just flashes keep having to unplug and restart the device once do that it starts working again so irritating this device could really be great device if google and amazon would act like grownups","pred_label":""},{"clean_reviews":"overall it great and like that can see lyrics and the time and date however sometimes it freezes and doesn respond properly no error message about lack of connectivity it just stops resetting resolves the problem","pred_label":""},{"clean_reviews":"great product","pred_label":""},{"clean_reviews":"good device","pred_label":""},{"clean_reviews":"love my echo dot looks brand new and works perfect very satisfied","pred_label":""},{"clean_reviews":"great fun but frustrating at times commands between tv and the show get mixed asking to watch something will turn my directv not display on show which stinks with an 8 year old also would like more video options with flash briefings still really tech wonder for low price ...
#   ```
#
# Now processing batch#: 2 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"the speakers arent too loud alexa is great though besides that naw","pred_label":""},{"clean_reviews":"love it","pred_label":""},{"clean_reviews":"very fun to use and having morning briefing","pred_label":""},{"clean_reviews":"have only had it set up for few days still adding smart home devices to it the speaker is great for playing music like the size we have it stationed on the kitchen counter and it not intrusive to look at","pred_label":""},{"clean_reviews":"easy to set up plug it in then make some selections for your preferences such as language temp or etc am getting more familiar with it and will be adding my calendar and appointments","pred_label":""},{"clean_reviews":"couldn be more pleased amazon hit this one out of the park looks great and runs great love it","pred_label":""},{"clean_reviews":"so far all can say is love it","pred_label":""},{"clean_reviews":"it worked for month or so then it stopped ve tried everything to try and make it work but nothing is working want refund","pred_label":""},{"clean_reviews":"very bad this device don know if it because is refurbished or what but it activated by itself nobody is talking and he just activated and start talking when you talk you have to yell super lauded","pred_label":""},{"clean_reviews":"awesome product am in the process of having every room in my house set up with automation and the show is now my favorite device","pred_label":""},{"clean_reviews":"love our little dot don know what the original larger alexa can do that the dot cannot do but we are pleased with our dots capabilities","pred_label":""},{"clean_reviews":"easy set up","pred_label":""},{"clean_reviews":"excellent why didn think it is in the beginning love it","pred_label":""},{"clean_reviews":"works great in my large open room","pred_label":""},{"clean_reviews":"echo dot responds to us when we aren even talking to it ve unplugged it it feels like it 34 spying 34 on us","pred_label":""},{"clean_reviews":"love alexa love the echo dot but we have trouble with the speakers when using the intercom","pred_label":""},{"clean_reviews":"all the new amazon products have are great everything bought refurbished is complete garbage will never purchase amazon refurbished again total dissatisfaction","pred_label":""},{"clean_reviews":"would like to tell you that have reason to hate it like the speakers suck or the color or the shape or even the way it smells but can honestly say the number reason hate this device is have tried to set it up 3x now to no avail have 4 other echo devices already that set up and use quite regularly have reset my phone galaxy s8 checked the app for updates have cycled power to the echo unit with each attempt work in the network technology industry for living and have for over 20 years now so lack of experience or knowledge is not the problem here used the app and the device even tells me it is connected and to follow the app to continue set up the set up screen just continues to roll the 3 dots around the screen for about 5 minutes before the app locks up on my phone and have to force the app to close restart my phone and the echo and try again figured 3x was enough it shouldn be that hard techie can only imagine how bad this will prove to be for people whom have no clue about technology hope they won call me ll tell em to send the product back","pred_label":""},{"clean_reviews":"it works","pred_label":""},{"clean_reviews":"it easier to do things with it","pred_label":""},{"clean_reviews":"we love it finally got one for everyone in the home most importantly we re saving money that would have otherwise gone to cable","pred_label":""},{"clean_reviews":"just this for listening to talk radio in the morning and turning lights on and off etc the system does an excellent job as full house sound system streaming sirius","pred_label":""},{"clean_reviews":"great product except there is no possible way for it to act as clock the displays the time permanently when in clock mode th ...
#   ```
#
# Now processing batch#: 3 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"echo show white nbsp great new addition to our alexa home solution and now can call back home and video chat directly from my phone great way to stay in touch with family","pred_label":""},{"clean_reviews":"sure the echo is as cool as everyone says but won get to try this one even though have large covered porch the package was left on my top step on day forecast for 100 chance of rain and rain it did soaking the package not even going to open it and see how bad the damage is this order has been cursed from the beginning ordered as birthday gift and delivery was not made on scheduled day now get it and its rain soaked","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"the product sounded the same as the emoji speaker from five below my sister has and even that one has bluetooth and doesn need to be plugged in the only good thing about this is that you can speak to it","pred_label":""},{"clean_reviews":"ll be returning it it been nothing but annoying the hub can be turned off if not needed and it interferes with my hue bridge can even install philips lights with it unless unplug it to do so there are plenty of other reviews that go in depth with the issues bottom line is it sucks as hub it doesn support wave and zigbee which in fairness knew in advance but when the one protocol it does support doesn do many functions that dedicated one will what the point noticed right away that my philips hue bridge supports firmware upgrades to the light bulbs themselves and this doesn found that rather interesting","pred_label":""},{"clean_reviews":"item returned for repair receivded item back from repair 07 23 18 parts missing no power cord included please advise","pred_label":""},{"clean_reviews":"would be 5 stars if you could turn off the 34 things to try 34 screen should have read up on this before buying the spot amazon please update to enable us to turn this off it is so extremely annoying to look over to see the time but instead see 34 things to try 34","pred_label":""},{"clean_reviews":"when got this echo was excited to have device with better sound than my dot and hub to control some hue bulbs what didn realize and also wasn fully communicated to me is that you can use hue bulbs to their full potential with this device you can only turn on and off the lights and set them to number of preset colors you also cannot update the bulbs to the newest firmare which is security concern for me do not buy this if you want full featured hub for your new iot devices if you do you will end up needing to update to standalone hub which makes the hub inside this device redundant and pointless still love the echo and have zero complaints about the alexa functionality or sound quality of this device only disappointed with the hub functionalities","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"this device does not interact with my home filled with apple devices how disappointing","pred_label":""},{"clean_reviews":"works well not thrilled that most of the apps have to be paid for seprately","pred_label":""},{"clean_reviews":"best father day gift dad joked to my mom that alexa will be the one listening to all of his repeated stories going forward","pred_label":""},{"clean_reviews":"seems to work ok but no youtube tv really can believe they would ban an app that so many people want to use really wanted to like it but when couldn install that particular app it became almost useless almost does most other stuff just fine but ll stick with my roku","pred_label":""},{"clean_reviews":"love this thing people think crazy for paying this much for glorified alarm clock but don care for me waking up in good mood is pretty important and this helps me do it so glad don have to deal with my old eeaanh eeaanh eeaanh alarm very excited to say alexa turn off the lights smart plugs get here soon got camera privacy slide for this since it is in my bedroom","pred_label":""},{"clean_reviews":"amazing product ...
#   ```
#
# Now processing batch#: 4 of 4
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#
#   ```
#   [{"clean_reviews":"liked the sound what is troubling is that paid extra money to have access to million more songs sometimes it doesn work ex alexa play italian songs 34 don have or don 34 understand or play the opera tosca response 34 sorry don 34 have that","pred_label":""},{"clean_reviews":"easy to set up and use too bad it has to be plugged in would be nice to take it outside and operate on battery and recharged","pred_label":""},{"clean_reviews":"some times alexa is little 34 thick 34 but mostly good","pred_label":""},{"clean_reviews":"the first one quit working shortly after got it the next one becomes unresponsive to my voice at times and the only way to get it to work is through the app am not sure if it just this dot or they are all this way","pred_label":""},{"clean_reviews":"started taking on her own haven used it since unplugged it that day no one was talking my daughter was laying in bed next to be and she just started going on about the movie moana and completely scared the sh out of my daughter now","pred_label":""},{"clean_reviews":"no issues works and looks great","pred_label":""},{"clean_reviews":"we really only use this as speaker to stream music we ve had it 7 months and it just kinda useless","pred_label":""},{"clean_reviews":"works well and has no obvious issues from being refurbished","pred_label":""},{"clean_reviews":"bought it to go with my security camera system but it did not perform like thought it would it doesn alert us when someone is at the door also can talk to the person at the door through the echo show only through my cell phone","pred_label":""},{"clean_reviews":"love the product but very disappointed once realized can no longer play youtube videos now past my 30 days return date am realizing now have an expensive alarm clock am hoping youtube comes back was looking to buy an echo show for the kitchen during prime day glad didn","pred_label":""},{"clean_reviews":"am not tec smart enough to make it work at all will send it back if cant get help my eco dot works just fine this is too complacated just wanted bigger speaker","pred_label":""},{"clean_reviews":"haven had it week and already it cannot connect to my network tried reconnecting manually and the echo never appears in the list of devices to connect it will be on it way back to amazon","pred_label":""},{"clean_reviews":"we all love her","pred_label":""},{"clean_reviews":"used twice not working","pred_label":""},{"clean_reviews":"have it in the kitchen great for news or music in the can video call my daughter and grand kids really dig it","pred_label":""},{"clean_reviews":"it like siri in fact siri answers more accurately then alexa don see real need for it in my household though it was good bargain on prime day deals","pred_label":""},{"clean_reviews":"no it is broke and can get help fixing or replacing it","pred_label":""},{"clean_reviews":"wish volume was capable of going louder","pred_label":""},{"clean_reviews":"love it","pred_label":""},{"clean_reviews":"invasive and scared the crap out of me for speaking when it was not spoken to creapy af","pred_label":""},{"clean_reviews":"outstanding use all the time works just like they say","pred_label":""},{"clean_reviews":"unit came with the wrong plug will have to send back to amazon","pred_label":""},{"clean_reviews":"easy to use amazing","pred_label":""},{"clean_reviews":"poor quality gave it away","pred_label":""},{"clean_reviews":"just like new set up was quick easy","pred_label":""}]
#   ```

# %%
import json

df_total = pd.DataFrame()  # Initialize an empty DataFrame

for response in responses:
  # Clean the data by stripping the backticks
  json_data = response.text.strip("`")

  # Load the cleaned data and convert to DataFrame
  data = json.loads(json_data)
  df_temp = pd.DataFrame(data)

  # Concat the DataFrame to the final DataFrame
  #df_total = df_total.concat(df_temp, ignore_index=True)
  df_total = pd.concat([df_total, df_temp])


print(df_total)  # Display the final DataFrame
# Out:
#                                         clean_reviews  pred_label
# 0   our family bought several of these to help com...           0
# 1   am so disappointed in this product tried to in...           0
# 2   love our echo thing the full size version soun...           1
# 3   easy to install very clear speaker took one st...           1
# 4   do not understand all the excitement over thes...           0
# ..                                                ...         ...
# 20  outstanding use all the time works just like t...           1
# 21  unit came with the wrong plug will have to sen...           0
# 22                                easy to use amazing           1
# 23                          poor quality gave it away           0
# 24                just like new set up was quick easy           1
#
# [100 rows x 2 columns]

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_total['pred_label'] = df_total['pred_label'].values
test_set_total
# Out:
#                                                  review  label  \
# 1625  Our family bought several of these to help com...      0
# 1918  I am so disappointed in this product.  I tried...      0
# 678   Love our echo! Thing the full size version sou...      1
# 2017  Easy to Install. Very clear speaker. I took on...      1
# 1473  Do not understand all the excitement over thes...      0
# ...                                                 ...    ...
# 462   outstanding I use all the time....works just l...      1
# 2023  Unit came with the wrong plug, will have to se...      0
# 976                                easy to use--amazing      1
# 382                         Poor quality. Gave it away.      0
# 638             Just like new, set-up was quick & easy.      1
#
#                                           clean_reviews  pred_label
# 1625  our family bought several of these to help com...           0
# 1918  am so disappointed in this product tried to in...           0
# 678   love our echo thing the full size version soun...           1
# 2017  easy to install very clear speaker took one st...           1
# 1473  do not understand all the excitement over thes...           0
# ...                                                 ...         ...
# 462   outstanding use all the time works just like t...           1
# 2023  unit came with the wrong plug will have to sen...           0
# 976                                 easy to use amazing           1
# 382                           poor quality gave it away           0
# 638                 just like new set up was quick easy           1
#
# [100 rows x 4 columns]

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix, accuracy_score

y_true = test_set_total["label"]
y_pred = test_set_total["pred_label"]

#confusion_matrix(y_true, y_pred)

## For a better display

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

print(f"\nAccuracy: {accuracy_score(y_true, y_pred)}")
# Out:
# Accuracy: 0.92

# %% [markdown]
# ## Batching API Calls: ChatGPT (Few Shot)

# %%
test_set.shape
# Out:
# (488, 3)

# %%
test_set_total = test_set.sample(100)

test_set_total['pred_label'] = ''

test_set_total
# Out:
#                                                  review  label  \
# 1267  I switched to google. The amazon helper is mor...      0
# 631   Eh. It’s works on and off. Half the time it do...      0
# 1742  I have been waiting for the Echo Show to go on...      1
# 1563  It's like having another kid in the house; I h...      0
# 1517  Love my echo show! Great sound and picture. Do...      1
# ...                                                 ...    ...
# 2560                  Love the echo dot it’s amaxing!!!      1
# 2013  I bought this for myself and i didn’t realize ...      0
# 2520                           Best purchase this year.      1
# 1200                                                Meh      0
# 1682  So far so good,  much better sound than my Ech...      1
#
#                                           clean_reviews pred_label
# 1267  switched to google the amazon helper is more f...
# 631   eh it works on and off half the time it does n...
# 1742  have been waiting for the echo show to go on s...
# 1563  it like having another kid in the house have t...
# 1517  love my echo show great sound and picture does...
# ...                                                 ...        ...
# 2560                       love the echo dot it amaxing
# 2013  bought this for myself and didn realize it had...
# 2520                            best purchase this year
# 1200                                                meh
# 1682  so far so good much better sound than my echo dot
#
# [100 rows x 4 columns]

# %%
batches = []
batch_size = 50

for i in range(0, len(test_set_total), batch_size):
  batches.append(test_set_total[i : i + batch_size])  # Append batches instead of assigning

# %%
import time

def gpt_completion_function(batch,current_batch,total_batch,train_sample,model="gpt-3.5-turbo-1106"):
  """Function works in three steps:
  # Step-1: Convert the DataFrame to JSON using the to_json() method.
  # Step-2: Preparing the Gemini Prompt
  # Step-3: Calling GPT API
  """

  print(f"Now processing batch#: {current_batch+1} of {total_batch}")

  json_data = batch[['clean_reviews','pred_label']].to_json(orient='records')

  sample_json_data = train_sample[['clean_reviews','label']].to_json(orient='records')

  prompt = f"""You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
  Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
  Customer reviews are provided between three backticks below.
  In your output, only return the Json code back as output - which is provided between three backticks.
  Your task is to update predicted labels under 'pred_label' in the Json code.
  Don't make any changes to Json code format, please.
  Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
  Examples of good Sentiment Analysis Classification are provided between separator ####.
  These examples are for your reference, not to be included in your final output.

  ```
  {json_data}
  ```
  ####
  {sample_json_data}
  ####
  """

  print(prompt)

  messages = [{"role": "user", "content": prompt}]
  response = openai.ChatCompletion.create(model=model,messages=messages,temperature=0)
  time.sleep(5)
  return response.choices[0].message["content"]

# %%
train_sample = train_set.sample(4)

batch_count = len(batches)
responses = []

for i in range(0,len(batches)):
  responses.append(gpt_completion_function(batches[i],i,batch_count,train_sample))
# Out:
# Now processing batch#: 1 of 2
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#   Examples of good Sentiment Analysis Classification are provided between separator ####.
#   These examples are for your reference, not to be included in your final output.
#
#   ```
#   [{"clean_reviews":"switched to google the amazon helper is more for shopping and google is the tasks assistant","pred_label":""},{"clean_reviews":"eh it works on and off half the time it does not respond when you say wake up name other then that works fine","pred_label":""},{"clean_reviews":"have been waiting for the echo show to go on sale and it was worth the wait it was easy to set up and start using","pred_label":""},{"clean_reviews":"it like having another kid in the house have to constantly repeat myself can tell alexa to do something clear as day and according to the history she hears something comeletely different the device is really cool and like the concept which is why it gets two stars however it just doesn work as intended find myself irritated more often than not when use this device","pred_label":""},{"clean_reviews":"love my echo show great sound and picture does great job thing in my entire echo collection","pred_label":""},{"clean_reviews":"thought it was pretty cool new to streaming thing seemed easy to use","pred_label":""},{"clean_reviews":"have an echo but wanted dot for my bedroom it was even easier to set up than my original echo","pred_label":""},{"clean_reviews":"very convenient","pred_label":""},{"clean_reviews":"good speaker for bedroom or office","pred_label":""},{"clean_reviews":"cool","pred_label":""},{"clean_reviews":"need to be able to connect to more 3rd party viceo apps","pred_label":""},{"clean_reviews":"the only negative we have on this product is the terrible sound quality massive difference from the alexa which to us was big reason we wanted to purchase this won be buying another until the speaker and sound quality can improve","pred_label":""},{"clean_reviews":"liked it until on day after year it no longer worked would not power up and go past the firestick logo on tv bought second one will not buy third if this one doesn last longer","pred_label":""},{"clean_reviews":"love the echo purchased it for company for my husband he is 83 and alexa is great all he has to do is say her name and she tells him joke and plays his favorite songs","pred_label":""},{"clean_reviews":"the echo is an amazing device many times it seems very intuitive but at other times ask for something that seems clear and simple and get no result installation was fairly straightforward but messed up several times simply because thought step was complete when it wasn this actually made me lose ground until figured that out my advice is to be patient the app will let you know when you can move on to the next step my biggest issue of the moment is that we have several echo devices in our home and would like to use them as intercoms which am told can be done however can make any of the echos aware of the others existence when ask alexa how to do this she answers about instructions how to change her name know this is likely my fault but would think the designers would anticipate this and make it easier to find the needed instructions small deal for many device savvy people but challenge for me","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"as an alexa device it works just as well as any of the other products unfortunately it doesn go up from there the ability to play videos is very limited you can not play youtube and when you can play video the cropping of the screen makes it look very strange there is quite selection of clock faces and you can control what is displays with one glaring and very annoying exception you can turn off the 34 things to try 34 screen you can turn off the screen scroll but that defeats the purpose of having the screen don need to be reminded every 5 seconds what things can do with alexa don need the advertising especially at the cost of this device overall its an expensive alexa device with screen that not very useful and annoying would not recommend this until the amazon people get their act together and come up with screen that actually useful","pred_label":""},{"clean ...
#   ```
#   ####
#   [{"clean_reviews":"very easy to set up works wonderful and love it","label":1},{"clean_reviews":"it alexa what else can you say","label":1},{"clean_reviews":"device was not working followed all instructions for alexa echo dot and it did not come on very upsetting","label":0},{"clean_reviews":"","label":0}]
#   ####
#
# Now processing batch#: 2 of 2
# You are an expert linguist, who is good at classifying customer review sentiments into Positive/Negative labels.
#   Help me classify customer reviews into: Positive(label=1), and Negative(label=0).
#   Customer reviews are provided between three backticks below.
#   In your output, only return the Json code back as output - which is provided between three backticks.
#   Your task is to update predicted labels under 'pred_label' in the Json code.
#   Don't make any changes to Json code format, please.
#   Error handling instruction: In case a Customer Review violates API policy, please assign it default sentiment as Negative (label=0).
#   Examples of good Sentiment Analysis Classification are provided between separator ####.
#   These examples are for your reference, not to be included in your final output.
#
#   ```
#   [{"clean_reviews":"4 5 out of 5 stars generally like this product its great at doing what you ask of it like playing music setting timers and making calls reason why didn rate it 5 out of 5 is that sometimes the connection dies and my echo stops playing music and shows red ring seems to be connection issue overall great product","pred_label":""},{"clean_reviews":"don like that it goes into sleep mode after 20 30 minutes of inactivity shouldn have to wake up the fire tv to finish watching show","pred_label":""},{"clean_reviews":"still learning all the capabilities but so far pretty pretty pretty good","pred_label":""},{"clean_reviews":"this product currently has two related software flaws that make it completely unusable 1 there is 34 card 34 on the homescreen called 34 things to try 34 it an ad for other alexa services you can try you can turn off all the other homescreen cards but not this one 2 by default the homescreen cards 34 cycle 34 automatically which is incredibly annoying there is setting where you can opt to have the cards only 34 cycle once 34 instead of 34 cycle continuously 34 but critically this setting does not work my unit has been set to 34 cycle once 34 and the cards still continue to cycle all the time have rebooted the device re set etc etc until these two obvious software issues are fixed in my opinion the product is useless","pred_label":""},{"clean_reviews":"still unable to connect any devices although it says it has built in hub so bought bridge to connect the devices thinking that everything would sync and my other devices are still not discovered via my echo plus and was looking forward to this feature being able to play music check the weather etc is fine","pred_label":""},{"clean_reviews":"las pel\u00edculas no tiene no se pueden cambiar espa\u00f1ol t\u00edtulos en espa\u00f1ol","pred_label":""},{"clean_reviews":"am so disappointed in this product tried to install two different units and neither one of them were successfully completed hours with amazon technicians resetting each of them the app didn connect the echo plus to the internet connection tried using the application on phone tablet and on chromebook no luck there are no clean directions on the application probably sending this back to amazon mark this as not ready for prime time","pred_label":""},{"clean_reviews":"looks and works perfect glad got good deal","pred_label":""},{"clean_reviews":"sent it back due to crackling noise and turning itself off and on but what can you expect with refurbished item","pred_label":""},{"clean_reviews":"works great","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"brought to replace one that moved and doesn have the same range as my previous non refurbished unit it would seldom be able to find the wi fi and couldn connect got tired of hearing the message 34 trouble connecting check the alexa app 34 and just unplugged it went through the troubleshooting and reconnected it several times it just not as strong","pred_label":""},{"clean_reviews":"love alexa am surprised how much use her","pred_label":""},{"clean_reviews":"product turns on randomly and sometimes at night","pred_label":""},{"clean_reviews":"received the wrong product was so excited to install it all excitement gone thank you amazon","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"doesn always respond when spoken to with promp word thought it would connect to my echo upstairs and use it like an intercom haven been able to do that","pred_label":""},{"clean_reviews":"","pred_label":""},{"clean_reviews":"didn like that almost everytime asked alexa question she would say dont know that or havent learned that","pred_label":""},{"clean_reviews":"the sound on these is terrible it like tin can love my echo but this item is awful","pred_label":""},{"clean_reviews":"works good for the most part you ask it some questions and she says she doesn know thought she was supposed to know everything","pred_label":""} ...
#   ```
#   ####
#   [{"clean_reviews":"very easy to set up works wonderful and love it","label":1},{"clean_reviews":"it alexa what else can you say","label":1},{"clean_reviews":"device was not working followed all instructions for alexa echo dot and it did not come on very upsetting","label":0},{"clean_reviews":"","label":0}]
#   ####

# %%
import json

df_total = pd.DataFrame()  # Initialize an empty DataFrame

for response in responses:
  # Clean the data by stripping the backticks
  json_data = response.strip("`")

  # Load the cleaned data and convert to DataFrame
  data = json.loads(json_data)
  df_temp = pd.DataFrame(data)

  # Append the DataFrame to the final DataFrame
  df_total = df_total.append(df_temp, ignore_index=True)

print(df_total)  # Display the final DataFrame
# Out:
#                                         clean_reviews  pred_label
# 0   switched to google the amazon helper is more f...           0
# 1   eh it works on and off half the time it does n...           0
# 2   have been waiting for the echo show to go on s...           1
# 3   it like having another kid in the house have t...           0
# 4   love my echo show great sound and picture does...           1
# ..                                                ...         ...
# 95                       love the echo dot it amaxing           1
# 96  bought this for myself and didn realize it had...           0
# 97                            best purchase this year           1
# 98                                                meh           0
# 99  so far so good much better sound than my echo dot           1
#
# [100 rows x 2 columns]
# <ipython-input-85-6f10fdd72bc6>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total = df_total.append(df_temp, ignore_index=True)
# <ipython-input-85-6f10fdd72bc6>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_total = df_total.append(df_temp, ignore_index=True)

# %%
# prompt: Overwrite pred_label from 'df' into pred_label in 'train_set_sample'

test_set_total['pred_label'] = df_total['pred_label'].values
test_set_total
# Out:
#                                                  review  label  \
# 1267  I switched to google. The amazon helper is mor...      0
# 631   Eh. It’s works on and off. Half the time it do...      0
# 1742  I have been waiting for the Echo Show to go on...      1
# 1563  It's like having another kid in the house; I h...      0
# 1517  Love my echo show! Great sound and picture. Do...      1
# ...                                                 ...    ...
# 2560                  Love the echo dot it’s amaxing!!!      1
# 2013  I bought this for myself and i didn’t realize ...      0
# 2520                           Best purchase this year.      1
# 1200                                                Meh      0
# 1682  So far so good,  much better sound than my Ech...      1
#
#                                           clean_reviews  pred_label
# 1267  switched to google the amazon helper is more f...           0
# 631   eh it works on and off half the time it does n...           0
# 1742  have been waiting for the echo show to go on s...           1
# 1563  it like having another kid in the house have t...           0
# 1517  love my echo show great sound and picture does...           1
# ...                                                 ...         ...
# 2560                       love the echo dot it amaxing           1
# 2013  bought this for myself and didn realize it had...           0
# 2520                            best purchase this year           1
# 1200                                                meh           0
# 1682  so far so good much better sound than my echo dot           1
#
# [100 rows x 4 columns]

# %%
# Plotting confusion matrix on the predictions

from sklearn.metrics import confusion_matrix, accuracy_score

y_true = test_set_total["label"]
y_pred = test_set_total["pred_label"]

print(confusion_matrix(y_true, y_pred))
print(f"\nAccuracy: {accuracy_score(y_true, y_pred)}")
# Out:
# [[49  0]
#  [ 9 42]]
#
# Accuracy: 0.91
